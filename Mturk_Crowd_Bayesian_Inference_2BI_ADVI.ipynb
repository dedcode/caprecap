# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from tqdm import tqdm
import numpy as np
import pandas as pd
import pymc3 as pm
from theano import shared
import theano.tensor as tt
import theano
from pymc3.distributions.dist_math import binomln, betaln, bound
np.set_printoptions(suppress=True)
# Out:
# Using cuDNN version 7104 on context None
# Mapped name None to device cuda0: GeForce GTX 1080 Ti (0000:86:00.0)
# /Users/ded/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Helper function for visualization
def plot_traces(trcs, varnames=None):
    '''Plot traces with overlaid means and values'''

    nrows = len(trcs.varnames)
    if varnames is not None:
        nrows = len(varnames)

    ax = pm.traceplot(trcs, varnames=varnames, figsize=(12,nrows*1.4),
                      lines={k: v['mean'] for k, v in
                             pm.summary(trcs,varnames=varnames).iterrows()})

    for i, mn in enumerate(pm.summary(trcs, varnames=varnames)['mean']):
        ax[i,0].annotate('{:.2f}'.format(mn), xy=(mn,0), xycoords='data',
                         xytext=(5,10), textcoords='offset points', rotation=90,
                         va='bottom', fontsize='large', color='#AA0022')
def strip_derived_rvs(rvs):
    '''Remove PyMC3-generated RVs from a list'''

    ret_rvs = []
    for rv in rvs:
        if not (re.search('_log',rv.name) or re.search('_interval',rv.name)):
            ret_rvs.append(rv)
    return ret_rvs

# %%
# Load the data and process it.

df = pd.read_csv("mturk_surveys.csv")
df["hit_answered_date"]=pd.to_datetime(df["hit_answered_date"])
df['date'] = pd.to_datetime(df['hit_answered_date'].apply(lambda x : x.date()))

# Calculate the time period of each survey answer. 
# Below we take out time period to be 30-day periods. 
# We can change this to be weeks, months, or anything else
window_length = 30
minDate = min(df['date'])
df['period'] = (df['date'] - minDate).dt.days // window_length 

df = df[df['period'] < 35]

# Create a list of all unique worker IDs 
workers = pd.DataFrame(list(set(df.worker_id)), columns=['worker_id']).reset_index().set_index('worker_id')

# Fix the issue of duplicate records within the same period.
data = df[['worker_id', 'period']].drop_duplicates().pivot_table(
    index = 'worker_id',
    values = 'period',                    
    aggfunc=('count','min','max')
).join(workers).set_index('index').sort_index()

# Aggregate the capture histories
data = data.groupby(['min', 'max', 'count']).size().reset_index(name='count_history')

# %%
data.head(10)
# Out:
#    min  max  count  count_history
# 0    0    0      1            928
# 1    0    1      2             57
# 2    0    2      2             55
# 3    0    2      3              8
# 4    0    3      2             44
# 5    0    3      3             13
# 6    0    3      4              2
# 7    0    4      2             26
# 8    0    4      3             17
# 9    0    4      4              2

# %%
# Summary of input

S = df['period'].max() + 1
V = len(workers)
freqs = data['count_history'].values
H = len(freqs)

print('Sampling periods:', S)
print('Unique patterns:', H)
print('Unique workers:', V)
# Out:
# Sampling periods: 35
# Unique patterns: 3802
# Unique workers: 46114

# %%
# We want to see the survival marks to compute the total survival
# e.g, Arrive: 1, Depart: 2 => 011
# Dims: SxSxS
def make_survival(S):
    mask = np.zeros([S,S,S])  # arrival, departure, presence_sequence
    for s in np.arange(S):
        for q in np.arange(s,S):
            c1 = np.zeros(s)
            c2 = np.ones(q-s)
            c3 = np.zeros(S-q)
            mask[s,q]= np.concatenate((c1, c2, c3))
    return mask
survival = tt.constant(make_survival(S))

# %%
# A more compact way to represent all Arrival and departures from the data
# This is part of the input data, so we preprocess it!
def get_hmask(S, H, data):
    h_mask = np.zeros((H,S,S))
    for wh in np.arange(H):
        f, l = data['min'].values[wh] , data['max'].values[wh]
        h_mask[wh, :f+1, l:] = 1
    return h_mask
hmask = tt.constant(get_hmask(S, H, data))
hmask.shape
# Out:
# Shape.0

# %%
# For a given outcome in {1,S} (Frequency of capture that's not 0) 
# Generate the Binomial parameters n and i   choose(n, i)
# Nn is the duration from arrival to departure
# Ni is the Frequency we are intersted in
# Dim: SxSxS
def make_binmask(S, data):
    i = data['count'].values
    i = i[:, np.newaxis, np.newaxis] *  np.ones((H, S, S))
    n = np.broadcast_to(np.triu(np.ones([S,S]), 0).cumsum(axis =1), (H, S, S))
    return tt.constant(i), tt.constant(n)
Ni, Nn = make_binmask(S, data)
print('Tensor with number of captures', Ni.shape)
print('Tensor with durations from first to last seen', Nn.shape)
# Out:
# Tensor with number of captures Shape.0
# Tensor with durations from first to last seen Shape.0

# %%
# Helper functions for the Beta Bernoulli Process
# TODO: switch to a single function even for the special case of 0 captures.

def get_BetaBi(a,b, S, Ni, Nn, mix):
    # The beta binomial
    BBi  =  tt.log(1-mix) + bound(betaln(Ni + a+1, Nn - Ni + b) - betaln(a+1, b),
                     Ni >= 0, Ni <= Nn,
                     a > 0, b > 0)
    # The above is the computation of the log, so we take the exponent
    return tt.exp(BBi)

def get_BetaB0(a, b, S, mix):
    # The beta binomial for 0 captures
    Nn = tt.triu(tt.ones([S,S]), 0).cumsum(axis =1).eval()
    #B0 = tt.gammaln(n + b) - tt.gammaln(n + a + b) + tt.gammaln(a + b) - tt.gammaln(b)
    B0 = tt.log(1-mix) + bound(betaln(a, Nn + b) - betaln(a, b), 
               a > 0, b > 0)
    return tt.exp(B0)

# %%
def logp_capture(arrival_probs, departure_probs, mix, p1, p2, U, survival_mask, Ni, Nn, S, V):
    def ll_capture_f(Nh, data_first_last_mask):
          
        # useful vars 
        
        # Likelihood of observing Li captures
        
        # compute the survival
        survival_prob = tt.pow(1 - departure_probs, survival_mask)
        survival_prob = tt.prod(survival_prob, axis=2)
        # compute the arrival and departure
        LAD      = arrival_probs[:, np.newaxis] * survival_prob * departure_probs    # SxS
        # keep only true possibilites
        True_LAD = LAD * data_first_last_mask # HxSxS
        
        
        # Li Likelihood
        LiBin = tt.log(mix) + Ni * tt.log(p1) + (Nn-Ni) * tt.log(1-p1)
        LiBin = tt.exp(LiBin)
        LiBin = tt.batched_tensordot(True_LAD, LiBin, axes = 2)
        
        # sum along the freqencies of catpures
        LiBB = tt.log(1-mix) + Ni * tt.log(p2) + (Nn-Ni) * tt.log(1-p2)
        LiBB = tt.exp(LiBB)
        LiBB = tt.batched_tensordot(True_LAD, LiBB, axes = 2)
        
        Li = LiBin + LiBB
        
        # Likelihood of No-Capture L0
        True_LAD0    = LAD * tt.triu(tt.ones((S,S)), 0)
        
        L0Bin  = tt.log(mix) + Nn * tt.log(1-p1)
        L0Bin  = tt.exp(L0Bin)
        L0Bin  = tt.sum(True_LAD0 * L0Bin)
        
        L0BB  = tt.log(1-mix) + Nn * tt.log(1-p2)
        L0BB  = tt.exp(L0BB)
        L0BB  = tt.sum(True_LAD0 * L0BB)
        
        L0 = L0Bin + L0BB
        
        # Multinomial
        obj1 = tt.gammaln(V + U + 1) - tt.gammaln(U + 1) - tt.sum(tt.gammaln(Nh+1))
        obj2 = tt.sum(Nh * tt.log(Li))
        obj3 = U * tt.log(L0)
        
        objective = obj1 + obj2 + obj3 
        
        return objective
    
    return ll_capture_f

# %%
# custom log-liklihood
# model
with pm.Model() as model:
    # parameters
    U = pm.Uniform('Unseen', lower=1, upper=300000)
    mix = pm.Uniform('mix', 0.000001, 0.999999)
    p1 = pm.Uniform('p1', 0.5, 0.999999)
    p2 = pm.Uniform('p2', 0.000001, 0.5)
    phi = tt.zeros(S)
    phi_v = pm.Uniform('departure', 0.001e-12, .2, shape=S-1)
    phi = tt.set_subtensor(phi[S-1], 1.)
    phi = tt.set_subtensor(phi[:S-1],phi_v)
    
    arr    = pm.Dirichlet('arrival', a=np.array([1./S]*S), shape=S)
    
    # Model Log-likelihood
    ob = pm.DensityDist('x', logp_capture(arr, phi, mix, p1, p2, U, survival, Ni, Nn, S, V), 
                        observed={'Nh': freqs ,
                                  'data_first_last_mask': hmask })
    inference = pm.ADVI()

# %% [markdown]
# # ADVI Sampling

# %%
# "Super fast Sampling" using ADVI
with model:
    s = theano.shared(pm.floatX(1))
    inference = pm.ADVI(cost_part_grad_scale=s)
    # ADVI has nearly converged
    #inference.fit(n=10000)
    # It is time to set `s` to zero
    #s.set_value(0)
    approx   = inference.fit(n=50000)
    trace_vi = approx.sample(5000) 
    elbos1 = -inference.hist
# Out:
# Average Loss = -2.3984e+06: 100%|██████████| 50000/50000 [9:54:59<00:00,  1.40it/s]
# Finished [100%]: Average Loss = -2.3984e+06

# %%
plt.plot(elbos1)

# %%
pm.traceplot(trace_vi);
# Out:
# /Users/ded/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3449: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')

# %% [markdown]
# ##### pm.summary(trace_vi)

# %%
# Percentage of Super-population Arrivals
plt.bar(np.arange(S), trace_vi['arrival'][-1])

# %%
# Percentage of Departures
plt.bar(np.arange(S-1), trace_vi['departure'][-1])

# %%
# "Super fast Sampling" using ADVI
with model:
    s = theano.shared(pm.floatX(1))
    inference = pm.ADVI(cost_part_grad_scale=s)
    # ADVI has nearly converged
    inference.fit(n=5000)
    # It is time to set `s` to zero
    s.set_value(0)
    approx = inference.fit(n=2000)
    trace_vi = approx.sample(1000) 
    elbos1 = -inference.hist

# %%
pm.traceplot(trace_vi);

# %%
with model:
    trace_vi = approx.sample(1000000) 
    elbos1 = -inference.hist

# %%
pm.traceplot(trace_vi);

# %%
pm.summary(trace_vi)
# Out:
#                         mean            sd    mc_error        hpd_2.5  \
# Unseen         242389.199243  26012.690644  400.255110  189848.328020
# mix                 0.802659      0.079494    0.001182       0.646739
# p1                  0.208667      0.103096    0.001490       0.045752
# p2                  0.206406      0.100777    0.001584       0.049108
# departure__0        0.152725      0.020966    0.000284       0.110600
# departure__1        0.155564      0.019894    0.000236       0.115328
# departure__2        0.156612      0.019071    0.000285       0.118681
# departure__3        0.157435      0.018659    0.000288       0.120079
# departure__4        0.157311      0.019002    0.000233       0.120115
# departure__5        0.157350      0.019148    0.000278       0.119100
# departure__6        0.156936      0.018873    0.000289       0.119594
# departure__7        0.156617      0.019320    0.000278       0.119154
# departure__8        0.156640      0.018712    0.000241       0.117570
# departure__9        0.156048      0.019263    0.000250       0.118470
# departure__10       0.156063      0.018944    0.000253       0.118276
# departure__11       0.155200      0.019716    0.000272       0.116876
# departure__12       0.155535      0.020218    0.000250       0.114078
# departure__13       0.155625      0.019357    0.000256       0.116257
# departure__14       0.155789      0.019817    0.000288       0.117366
# departure__15       0.156117      0.019319    0.000276       0.119576
# departure__16       0.156309      0.018855    0.000274       0.117729
# departure__17       0.156261      0.019234    0.000274       0.118480
# departure__18       0.155818      0.019409    0.000272       0.117996
# departure__19       0.156028      0.019474    0.000288       0.115508
# departure__20       0.156867      0.018988    0.000265       0.119438
# departure__21       0.156456      0.019385    0.000256       0.116738
# departure__22       0.156722      0.018932    0.000236       0.118344
# departure__23       0.157478      0.018581    0.000276       0.119430
# departure__24       0.157735      0.018718    0.000252       0.121526
# departure__25       0.157651      0.019452    0.000271       0.119439
# ...                      ...           ...         ...            ...
# arrival__5          0.013754      0.006544    0.000090       0.004230
# arrival__6          0.012899      0.006038    0.000092       0.003550
# arrival__7          0.012827      0.006015    0.000085       0.003703
# arrival__8          0.012381      0.005752    0.000084       0.004000
# arrival__9          0.012438      0.005672    0.000075       0.003745
# arrival__10         0.012598      0.005847    0.000091       0.003590
# arrival__11         0.012574      0.006070    0.000078       0.003378
# arrival__12         0.013040      0.006039    0.000083       0.003923
# arrival__13         0.014159      0.006538    0.000094       0.004428
# arrival__14         0.014831      0.006773    0.000094       0.004841
# arrival__15         0.013573      0.006578    0.000096       0.004011
# arrival__16         0.013422      0.006169    0.000090       0.003970
# arrival__17         0.013527      0.006607    0.000100       0.003625
# arrival__18         0.013801      0.006667    0.000086       0.003674
# arrival__19         0.013725      0.006697    0.000095       0.003726
# arrival__20         0.014249      0.007068    0.000109       0.003536
# arrival__21         0.015072      0.007109    0.000098       0.004349
# arrival__22         0.015872      0.007743    0.000107       0.004530
# arrival__23         0.016713      0.008467    0.000124       0.004192
# arrival__24         0.017731      0.008770    0.000126       0.004583
# arrival__25         0.019063      0.009444    0.000121       0.004906
# arrival__26         0.020411      0.009756    0.000136       0.005070
# arrival__27         0.022206      0.010760    0.000141       0.006234
# arrival__28         0.024500      0.012221    0.000169       0.006475
# arrival__29         0.027582      0.013540    0.000204       0.007617
# arrival__30         0.032216      0.015439    0.000195       0.008336
# arrival__31         0.039331      0.018701    0.000264       0.008467
# arrival__32         0.051045      0.024760    0.000353       0.010341
# arrival__33         0.077548      0.035923    0.000520       0.018896
# arrival__34         0.278469      0.047414    0.000626       0.177937
#
#                     hpd_97.5
# Unseen         284175.010579
# mix                 0.937125
# p1                  0.413717
# p2                  0.411182
# departure__0        0.187914
# departure__1        0.187956
# departure__2        0.188087
# departure__3        0.187881
# departure__4        0.188829
# departure__5        0.188558
# departure__6        0.189637
# departure__7        0.189507
# departure__8        0.186775
# departure__9        0.188568
# departure__10       0.187678
# departure__11       0.187667
# departure__12       0.187224
# departure__13       0.186990
# departure__14       0.189594
# departure__15       0.188771
# departure__16       0.187079
# departure__17       0.188469
# departure__18       0.188550
# departure__19       0.187086
# departure__20       0.188790
# departure__21       0.189362
# departure__22       0.187264
# departure__23       0.187019
# departure__24       0.189691
# departure__25       0.190001
# ...                      ...
# arrival__5          0.026508
# arrival__6          0.024936
# arrival__7          0.024736
# arrival__8          0.023893
# arrival__9          0.023882
# arrival__10         0.024516
# arrival__11         0.024375
# arrival__12         0.025148
# arrival__13         0.027415
# arrival__14         0.028763
# arrival__15         0.026662
# arrival__16         0.025726
# arrival__17         0.026794
# arrival__18         0.027166
# arrival__19         0.027421
# arrival__20         0.028169
# arrival__21         0.029154
# arrival__22         0.031823
# arrival__23         0.033734
# arrival__24         0.035682
# arrival__25         0.037836
# arrival__26         0.039009
# arrival__27         0.044041
# arrival__28         0.047942
# arrival__29         0.055159
# arrival__30         0.062745
# arrival__31         0.075753
# arrival__32         0.099126
# arrival__33         0.148590
# arrival__34         0.365456
#
# [73 rows x 5 columns]

# %%
approx = inference.fit(n=20000)

# %%
elbos1 = -approx.hist # shape = (10000,)
# get the fitted value
gbij = approx.bij
cov = approx.cov.eval()
means = gbij.rmap(approx.mean.eval())
sds = gbij.rmap(np.diag(cov)**.5)

# %%
plt.plot(elbos1)

# %%
means

# %%
pm.traceplot(approx.sample(2000));
